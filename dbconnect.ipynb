# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sqlalchemy import create_engine
engine=create_engine('postgresql://postgres:postgres@localhost:5432/hydro')
df=pd.read_sql('select * from Mtest_564 limit 100;',engine)
df
# Out:
#             event_time      date  top_spear  bottom_spear  chamber_lvl  \
# 0  2014-11-01 00:00:00  00:00:00       73.6          84.5         14.6
# 1  2014-11-01 00:01:00  00:01:00       71.8          82.5         15.1
# 2  2014-11-01 00:02:00  00:02:00       71.7          82.5         15.4
# 3  2014-11-01 00:03:00  00:03:00       71.8          82.4         15.3
# 4  2014-11-01 00:04:00  00:04:00       71.8          82.5         15.4
# ..                 ...       ...        ...           ...          ...
# 95 2014-11-01 01:35:00  01:35:00       76.9          88.6         17.6
# 96 2014-11-01 01:36:00  01:36:00       77.0          88.6         17.9
# 97 2014-11-01 01:37:00  01:37:00       77.0          88.6         17.7
# 98 2014-11-01 01:38:00  01:38:00       77.0          88.6         17.7
# 99 2014-11-01 01:39:00  01:39:00        0.0          88.6         17.8
#
#     active_power  river_lvl  penstock_pressure
# 0          709.0        8.1              10.68
# ...
